# %%
'''
print("amit")
print("learning")
print("python")
'''
print("machine learning")

# print("deep learning")
# print("data science")
# print("python")
# Out:
# machine learning

# %%
x = 4
x = 5
print(id(x))
# Out:
# 140719673930792

# %%
print("my name {0} , my age is {1}".format("Mohamed", 25))
print("my name {} , my age is {}".format("Mohamed", 25))
print("my name {x} , my age is {y}".format(x = "Mohamed", y = 25))
# Out:
# my name Mohamed , my age is 25
# my name Mohamed , my age is 25
# my name Mohamed , my age is 25

# %%
age = 25
name = "Mohamed"
print(f"my name is {name} , my age is {age}")
# Out:
# my name is Mohamed , my age is 25

# %%
your_name = "Mohamed"
your_age = 25
course_name = "AI"
print(f"my name is {your_name} , and i am {your_age} years old , I am engaged in learning {course_name}")
# Out:
# my name is Mohamed , and i am 25 years old , I am engaged in learning AI

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = [1, 2, 3, 4, 5]
print(type(x))
y = (1, 2, 3, 4, 5)
print(type(y))
z = {1, 2, 3, 4, 5}
print(type(z))
d = {"key1": 1, "key2": 2}
print(type(d))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>

# %%
name = "amit learning"
print(name[3])
print(name[0:4:2])
# Out:
# t
# ai

# %%
name = "amit learning"
print(name.upper())
print(name.replace("amit", "hello"))
# Out:
# AMIT LEARNING
# hello learning

# %%
info = ["I am", "learning", "AI", "diploma"]
sent = ' '.join(info)
print(sent)
# Out:
# I am learning AI diploma
