# %%
class Enrollment:
    '''Interface for enrollment-related operations'''
    def enroll(self, course):
        pass

class Assessment:
    '''Interface for assessment-related operations'''
    def assign_grade(self, student, course, score):
        pass


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def get_details(self):
        pass

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}, Email: {self.email}")

class Student(Person):
    def __init__(self, name : str, age, email, student_id, grade_level):
        super().__init__(name, age)
        self.email = email
        self.student_id = student_id
        self.grade_level = grade_level
        self.grades = []
        self.enolled_courses = []

    def get_details(self):
        '''implement get_details method'''
        return f"Name: {self.name}, Age: {self.age}, Email: {self.email}, Student ID: {self.student_id}, Grade Level: {self.grade_level}"
    
    def enroll_course(self, course):
        pass

    def calculate_gpa(self):
        pass

    def display_info(self):
        super().display()
        '''implement whatever you want'''

class Teacher(Person):
    def __init__(self, name, age, email, teacher_id, department, salary):
        super().__init__(name, age)
        self.email = email
        self.teacher_id = teacher_id
        self.department = department
        self.salary = salary
        self.courses_teaching = []

    def get_details(self):
        '''implement whatever you want'''
        pass

    def display_info(self):
        super().__init__()
        '''write what you want'''

    def teach_course(self, course):
        '''Assign a course to the teacher'''
        pass


class Course:
    def __init__(self, course_id, course_name, credits, schedule):
        self.course_id = course_id
        self.course_name = course_name
        self.credits = credits
        self.schedule = schedule
        self.teacher = None # Association with Teacher
        self.students = []  # Association with Student objects

    
    def add_student(self, student):
        '''Add a student to the course'''
        pass

    def remove_student(self, student):
        '''Remove a student from the course'''
        pass

    def set_teacher(self, teacher):
        '''Assign a teacher to the course'''
        pass

    def get_enrolled_count(self):
        '''Get the number of enrolled students'''
        pass

    def display_course_info(self):
        '''Display course information'''
        pass


class Grade:
    def __init__(self, student: Student, course: Course, score):
        self.grade_id = id(self)
        self.student = student # Association with Student
        self.course = course
        self.score = score
        self.letter_grade = self.calculate_letter_grade()


    def calculate_letter_grade(self):
        '''Calculate letter grade based on score'''
        pass

    def display_grade(self):
        '''Display grade information'''
        pass
