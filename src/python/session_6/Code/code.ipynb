# %% [markdown]
# #### The interface is a class without implementation
# #### Decomposition (Association, Agregation, Composition)
# #### Association: the relation between two entities is weak
# #### Composition: the relation between two entities is powerful remove one the other will colabse
# #### Agregation: the two entities dependant on each other

# %%
import pandas as pd
