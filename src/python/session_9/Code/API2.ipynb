# %% [markdown]
# API -> Application Programming Interface
# Serialization -> form any data to json
# Deserialization -> from json to any other form
# GET, POST, PUT, DELETE -> methods for API
# DNS -> Domain Naming Server
# Port -> is the gate to the server

# %%
#!pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\dell\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\dell\anaconda3\lib\site-packages (from pymongo) (2.8.0)

# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
from flask import Flask, request, jsonify

import threading
import time

# %%
app = Flask(__name__) # build a dumy API

client = MongoClient("mongodb://localhost:27017/")
db = client["CustomersDB"]
customers_col = db["Customers"]

# %%
@app.route('/customers', methods = ['GET'])
def get_customer():
    customers = []
    for doc in customers_col.find():
        doc['_id'] = str(doc['_id'])
        customers.append(doc)
    # serialize convert returned customers object to JSON format using jsonify
    return jsonify(customers)

# %%
@app.route('/add_customers', methods = ['POST'])
def add_customer():
     user_data = request.json
    if not user_data:
        return jsonify({"error": "No data provided"}), 400

    try:
        # Insert the document into the collection
        result = customers_col.insert_one({
            "Name": user_data["name"],
            "Age": user_data["age"],
            "Gender": user_data["gender"],
            "Region": user_data["region"]
        })
        
        # Return success message and the ID of the new document
        return jsonify({
            "message": "User added successfully",
            "id": str(result.inserted_id)
        }), 201 # 201 Created status code

    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
def run_flask():
    app.run(port=5000, debug=False, use_reloader=False)


threading.Thread(target = run_flask).start()
time.sleep(1)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %%
# consuming API

import requests

# %%
new_customer1 = {
    "name": "Cristiano Ronaldo",  
    "age": 40,              
    "gender": "Male",       
    "region": "Riadh"   
}

response = requests.post("http://127.0.0.1:5000/add_customers",new_customer1)
# Out:
# [2026-01-16 09:04:09,604] ERROR in app: Exception on /add_customers [POST]
# Traceback (most recent call last):
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 920, in full_dispatch_request
#     return self.finalize_request(rv)
#            ~~~~~~~~~~~~~~~~~~~~~^^^^
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 939, in finalize_request
#     response = self.make_response(rv)
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 1249, in make_response
#     raise TypeError(
#     ...<5 lines>...
#     )
# TypeError: The view function did not return a valid response. The return type must be a string, dict, list, tuple with headers or status, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [16/Jan/2026 09:04:09] "POST /add_customers HTTP/1.1" 500 -

# %%
response = requests.get("http://127.0.0.1:5000/customers")
print(response.json())
# Out:
# 127.0.0.1 - - [16/Jan/2026 09:04:13] "GET /customers HTTP/1.1" 200 -
# [{'Age': 30, 'Gender': 'Male', 'Name': 'Ahmed Hassan', 'Region': 'Cairo', '_id': '6964033e3eabaaaf8ffe777e'}, {'Age': 42, 'Gender': 'Male', 'Name': 'Mohamed Tarek', 'Region': 'Alexandria', '_id': '6964033e3eabaaaf8ffe777f'}, {'Age': 28, 'Gender': 'Female', 'Name': 'Heba Ali', 'Region': 'Giza', '_id': '6964033e3eabaaaf8ffe7780'}, {'Age': 35, 'Gender': 'Female', 'Name': 'Salma Nabil', 'Region': 'Mansora', '_id': '6964033e3eabaaaf8ffe7781'}, {'Age': 39, 'Gender': 'Male', 'Name': 'Youssef Adel', 'Region': 'Cairo', '_id': '6964033e3eabaaaf8ffe7782'}, {'Age': 25, 'Gender': 'Female', 'Name': 'Nourhan Samir', 'Region': 'Ismailia', '_id': '6964033e3eabaaaf8ffe7783'}, {'Age': 40, 'Gender': 'Male', 'Name': 'Ahmed Fahmy', '_id': '69640f293eabaaaf8ffe7788', 'region': 'Cairo'}, {'Age': 25, 'Gender': 'Male', 'Name': 'Saitama', '_id': '69640f293eabaaaf8ffe7789', 'region': 'Tokyo'}]
# 127.0.0.1 - - [16/Jan/2026 09:05:12] "GET /customers HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2026 09:05:14] "GET /customers HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2026 09:05:15] "GET /customers HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2026 09:22:45] "GET /customers HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2026 09:22:59] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [16/Jan/2026 09:23:00] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [16/Jan/2026 09:23:22] "GET /customers HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Jan/2026 09:24:05] "GET /add_customers HTTP/1.1" 405 -
# 127.0.0.1 - - [16/Jan/2026 09:25:37] "GET /add_customers"name":%20"Cristiano%20Ronaldo",%20"age":%2040,%20"gender":%20"Male",%20"region":%20"Riadh" HTTP/1.1" 404 -
# [2026-01-16 09:27:21,639] ERROR in app: Exception on /add_customers [POST]
# Traceback (most recent call last):
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 920, in full_dispatch_request
#     return self.finalize_request(rv)
#            ~~~~~~~~~~~~~~~~~~~~~^^^^
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 939, in finalize_request
#     response = self.make_response(rv)
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 1249, in make_response
#     raise TypeError(
#     ...<5 lines>...
#     )
# TypeError: The view function did not return a valid response. The return type must be a string, dict, list, tuple with headers or status, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [16/Jan/2026 09:27:21] "POST /add_customers HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Jan/2026 09:27:21] "GET /customers HTTP/1.1" 200 -
# [2026-01-16 09:28:00,712] ERROR in app: Exception on /add_customers [POST]
# Traceback (most recent call last):
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 920, in full_dispatch_request
#     return self.finalize_request(rv)
#            ~~~~~~~~~~~~~~~~~~~~~^^^^
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 939, in finalize_request
#     response = self.make_response(rv)
#   File "c:\Users\DELL\Desktop\AI97\AMIT_AI97\env\Lib\site-packages\flask\app.py", line 1249, in make_response
#     raise TypeError(
#     ...<5 lines>...
#     )
# TypeError: The view function did not return a valid response. The return type must be a string, dict, list, tuple with headers or status, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [16/Jan/2026 09:28:00] "POST /add_customers HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Jan/2026 09:28:00] "GET /customers HTTP/1.1" 200 -
